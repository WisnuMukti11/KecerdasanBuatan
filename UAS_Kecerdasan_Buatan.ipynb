# %% [markdown]
# <a href="https://colab.research.google.com/github/WisnuMukti11/KecerdasanBuatan/blob/main/UAS_Kecerdasan_Buatan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math 
import random

class Algoritma_genetika :
	jum_chrom = 6 
	gen = ["a", "b", "c", "d"] 
	nilai_per_gen = {
		'min' : 0,
		'max' : 10
	} 
    
	crossover_rate = 50/100 
	mutasi_rate = 10/100 
	total_gen = 24

	next_gen = np.arange(4)
	stop = False

	def __init__(self):
		self.first_chrom = np.random.randint(low=self.nilai_per_gen['min'], high=self.nilai_per_gen['max'], size=(self.jum_chrom, len(self.gen)))
		print("Inisialisasi")
		print(self.first_chrom)

	def evaluasi_chrom(self, chrom, generasi):
		print("GENERASI ["+str(generasi)+"] ------")
		
		jum_chromo = len(chrom)
		o = np.arange(jum_chromo)   
		fitness = np.arange(jum_chromo, dtype='f')
		
		for x in range(len(chrom)):
		
			fo = abs((chrom[x][0]+2*chrom[x][1]+3*chrom[x][2]+4*chrom[x][3])-30)
			o[x] = fo
			
			fitn = 1/(fo+1)
			
			fitness[x] = fitn
			if(fitn == 1):
				self.stop = True
			print("CHROMOSOME {0} : {1}, fitness = {2}".format(x, np.array2string(chrom[x], separator=','), fitn))
		print("Fitness Selesai!!")
		print(o)
		
		Probab = np.arange(jum_chromo, dtype='f')
		total_fitness = fitness.sum() 
		Probab = fitness / total_fitness 
		print("Total fitness : {}".format(str(total_fitness)))
		print("Rata-rata fitness : {}".format(str(np.average(fitness))))
		print("Probabilitas : {}".format(np.array2string(Probab, separator=',')))
		print("Probabilitas Paling Tinggi : {}, Pada chromosome ke {}".format(Probab[Probab.argmax()], str(Probab.argmax())))
		print("CHROMOSOME YANG MUNGKIN TERPILIH : {}".format(np.array2string(chrom[Probab.argmax()], separator=',')))
		print("")
		print("")
		self.next_gen = chrom[Probab.argmax()]

		C = np.arange(jum_chromo, dtype='f')
		total_x = 0
		for x in range(len(Probab)):
			total_x += Probab[x]
			C[x] = total_x

		R = np.random.sample(len(fitness))
		chrom_baru = np.arange(jum_chromo*len(self.gen)).reshape(jum_chromo, len(self.gen))

		for y in range(len(R)):
			for k in range(len(chrom_baru)):
				if(R[y] < C[0]):
					chrom_baru[y] = chrom[0]
				elif((C[k-1] < R[y]) & (R[y] < C[k])):
					chrom_baru[y] = chrom[k]

		R = np.random.sample(jum_chromo)
		index_chrom_parent = [] 
		for p in range(len(R)):
			if(R[p] < self.crossover_rate):
				index_chrom_parent.append(p)
    
		posisi_cros = np.random.randint(low=1, high=len(self.gen), size=len(index_chrom_parent))
		offspring = np.arange(len(self.gen)*len(index_chrom_parent)).reshape(len(index_chrom_parent), len(self.gen))
		for i_parent in range(len(index_chrom_parent)):
			index_chrome_1 = index_chrom_parent[i_parent]
			if(i_parent == len(index_chrom_parent)-1):
				index_chrome_2 = index_chrom_parent[0]
			else:
				index_chrome_2 = index_chrom_parent[i_parent+1]
			cut_point = posisi_cros[i_parent]
			for p in range(len(chrom_baru[index_chrome_1])):
				if(p >= posisi_cros[i_parent]):
					offspring[i_parent][p] = chrom_baru[index_chrome_2][p]
				else:
					offspring[i_parent][p] = chrom_baru[index_chrome_1][p]
		for x in range(len(offspring)):
			chrom_baru[index_chrom_parent[x]] = offspring[x]
		total_gen = len(chrom) * len(chrom[0])
		jum_mutasi = self.mutasi_rate * total_gen 
		jum_mutasi = int(jum_mutasi)

		random_i_mutasi = np.random.randint(low=0, high=total_gen, size=jum_mutasi)

		for x in range(len(random_i_mutasi)):
			index_mutasi = random_i_mutasi[x]
			byk_kromosom = len(chrom)
			byk_gen = len(chrom[0])
			random_value = random.randint(self.nilai_per_gen['min'], self.nilai_per_gen['max'])
			if(index_mutasi <= byk_gen):
				chrom_baru[0][index_mutasi-1]
			else:
				posisi_y = index_mutasi/byk_gen
				posisi_y = int(posisi_y)
				posisi_x = index_mutasi % byk_gen
				chrom_baru[posisi_y][posisi_x] = random_value
		return chrom_baru

	def do_now(self):
		chromosome_current = self.first_chrom
		for generasi in range(0, self.total_gen):
			if(self.stop != True):
				chromosome_current = self.evaluasi_chrom(chromosome_current, generasi)
		print("Selesai!")
		print("CHROMOSOME TERTINGGI DAN TERBAIK ADALAH")
		print(self.next_gen)

run = Algoritma_genetika()
run.do_now()
# Out:
# Inisialisasi
# [[2 1 2 0]
#  [8 1 9 0]
#  [9 4 0 7]
#  [7 3 8 2]
#  [5 7 4 1]
#  [1 9 6 1]]
# GENERASI [0] ------
# CHROMOSOME 0 : [2,1,2,0], fitness = 0.047619047619047616
# CHROMOSOME 1 : [8,1,9,0], fitness = 0.125
# CHROMOSOME 2 : [9,4,0,7], fitness = 0.0625
# CHROMOSOME 3 : [7,3,8,2], fitness = 0.0625
# CHROMOSOME 4 : [5,7,4,1], fitness = 0.16666666666666666
# CHROMOSOME 5 : [1,9,6,1], fitness = 0.08333333333333333
# Fitness Selesai!!
# [20  7 15 15  5 11]
# Total fitness : 0.54761904
# Rata-rata fitness : 0.09126984
# Probabilitas : [0.08695652,0.22826087,0.11413044,0.11413044,0.30434784,0.15217392]
# Probabilitas Paling Tinggi : 0.30434784293174744, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [5,7,4,1]
#
#
# GENERASI [1] ------
# CHROMOSOME 0 : [9,9,6,1], fitness = 0.05
# CHROMOSOME 1 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 2 : [9,4,0,7], fitness = 0.0625
# CHROMOSOME 3 : [8,1,4,6], fitness = 0.058823529411764705
# CHROMOSOME 4 : [7,9,6,1], fitness = 0.05555555555555555
# CHROMOSOME 5 : [1,9,0,7], fitness = 0.05555555555555555
# Fitness Selesai!!
# [19  9 15 16 17 17]
# Total fitness : 0.38243464
# Rata-rata fitness : 0.063739106
# Probabilitas : [0.1307413 ,0.2614826 ,0.16342662,0.15381329,0.14526811,0.14526811]
# Probabilitas Paling Tinggi : 0.2614825963973999, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,8,2]
#
#
# GENERASI [2] ------
# CHROMOSOME 0 : [7,9,6,1], fitness = 0.05555555555555555
# CHROMOSOME 1 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 2 : [7,9,6,1], fitness = 0.05555555555555555
# CHROMOSOME 3 : [7,9,6,2], fitness = 0.045454545454545456
# CHROMOSOME 4 : [1,3,8,7], fitness = 0.03333333333333333
# CHROMOSOME 5 : [ 1, 9,10, 1], fitness = 0.041666666666666664
# Fitness Selesai!!
# [17  9 17 21 29 23]
# Total fitness : 0.33156565
# Rata-rata fitness : 0.05526094
# Probabilitas : [0.16755523,0.3015994 ,0.16755523,0.13709064,0.10053314,0.12566642]
# Probabilitas Paling Tinggi : 0.3015994131565094, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,8,2]
#
#
# GENERASI [3] ------
# CHROMOSOME 0 : [7,9,6,2], fitness = 0.045454545454545456
# CHROMOSOME 1 : [1,3,1,2], fitness = 0.07692307692307693
# CHROMOSOME 2 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 3 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 4 : [7,9,6,2], fitness = 0.045454545454545456
# CHROMOSOME 5 : [1,3,8,7], fitness = 0.03333333333333333
# Fitness Selesai!!
# [21 12  9  9 21 29]
# Total fitness : 0.40116552
# Rata-rata fitness : 0.06686092
# Probabilitas : [0.11330622,0.19174898,0.24927367,0.24927367,0.11330622,0.08309123]
# Probabilitas Paling Tinggi : 0.24927367269992828, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,8,2]
#
#
# GENERASI [4] ------
# CHROMOSOME 0 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 1 : [1,3,1,2], fitness = 0.07692307692307693
# CHROMOSOME 2 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 3 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 4 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 5 : [5,3,8,7], fitness = 0.029411764705882353
# Fitness Selesai!!
# [ 9 12  9  9  9 33]
# Total fitness : 0.50633484
# Rata-rata fitness : 0.08438914
# Probabilitas : [0.19749777,0.15192136,0.19749777,0.19749777,0.19749777,0.05808758]
# Probabilitas Paling Tinggi : 0.19749777019023895, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,8,2]
#
#
# GENERASI [5] ------
# CHROMOSOME 0 : [1,3,1,2], fitness = 0.07692307692307693
# CHROMOSOME 1 : [1,3,8,3], fitness = 0.07142857142857142
# CHROMOSOME 2 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 3 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 4 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 5 : [5,3,8,7], fitness = 0.029411764705882353
# Fitness Selesai!!
# [12 13  9  9  9 33]
# Total fitness : 0.4777634
# Rata-rata fitness : 0.07962724
# Probabilitas : [0.16100663,0.14950617,0.20930862,0.20930862,0.20930862,0.06156136]
# Probabilitas Paling Tinggi : 0.20930862426757812, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,8,2]
#
#
# GENERASI [6] ------
# CHROMOSOME 0 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 1 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 2 : [5,3,8,2], fitness = 0.07142857142857142
# CHROMOSOME 3 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 4 : [1,3,1,3], fitness = 0.1111111111111111
# CHROMOSOME 5 : [1,3,1,2], fitness = 0.07692307692307693
# Fitness Selesai!!
# [ 9  9 13  3  8 12]
# Total fitness : 0.70946276
# Rata-rata fitness : 0.11824379
# Probabilitas : [0.14095172,0.14095172,0.10067981,0.35237932,0.15661302,0.10842441]
# Probabilitas Paling Tinggi : 0.35237932205200195, Pada chromosome ke 3
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,4,2]
#
#
# GENERASI [7] ------
# CHROMOSOME 0 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 1 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 2 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 3 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 4 : [7,3,6,2], fitness = 0.1
# CHROMOSOME 5 : [1,3,1,3], fitness = 0.1111111111111111
# Fitness Selesai!!
# [9 3 3 9 9 8]
# Total fitness : 0.9111112
# Rata-rata fitness : 0.15185186
# Probabilitas : [0.10975609,0.27439022,0.27439022,0.10975609,0.10975609,0.12195121]
# Probabilitas Paling Tinggi : 0.27439022064208984, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,4,2]
#
#
# GENERASI [8] ------
# CHROMOSOME 0 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 1 : [1,3,8,2], fitness = 0.1
# CHROMOSOME 2 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 3 : [1,3,4,4], fitness = 0.16666666666666666
# CHROMOSOME 4 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 5 : [1,3,1,2], fitness = 0.07692307692307693
# Fitness Selesai!!
# [ 3  9  3  5  3 12]
# Total fitness : 1.0935898
# Rata-rata fitness : 0.18226497
# Probabilitas : [0.22860491,0.09144197,0.22860491,0.15240328,0.22860491,0.07033998]
# Probabilitas Paling Tinggi : 0.22860491275787354, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,4,2]
#
#
# GENERASI [9] ------
# CHROMOSOME 0 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 1 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 2 : [2,3,4,2], fitness = 0.3333333333333333
# CHROMOSOME 3 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 4 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 5 : [1,3,4,2], fitness = 0.25
# Fitness Selesai!!
# [3 3 2 3 3 3]
# Total fitness : 1.5833334
# Rata-rata fitness : 0.2638889
# Probabilitas : [0.15789473,0.15789473,0.21052632,0.15789473,0.15789473,0.15789473]
# Probabilitas Paling Tinggi : 0.21052631735801697, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [2,3,4,2]
#
#
# GENERASI [10] ------
# CHROMOSOME 0 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 1 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 2 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 3 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 4 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 5 : [0,3,0,2], fitness = 0.058823529411764705
# Fitness Selesai!!
# [ 3  3  3  3  3 16]
# Total fitness : 1.3088236
# Rata-rata fitness : 0.21813726
# Probabilitas : [0.19101124,0.19101124,0.19101124,0.19101124,0.19101124,0.04494382]
# Probabilitas Paling Tinggi : 0.1910112351179123, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,4,2]
#
#
# GENERASI [11] ------
# CHROMOSOME 0 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 1 : [ 1, 3,10, 2], fitness = 0.0625
# CHROMOSOME 2 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 3 : [0,3,0,2], fitness = 0.058823529411764705
# CHROMOSOME 4 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 5 : [8,3,4,2], fitness = 0.2
# Fitness Selesai!!
# [ 3 15  3 16  3  4]
# Total fitness : 1.0713235
# Rata-rata fitness : 0.17855392
# Probabilitas : [0.23335621,0.05833905,0.23335621,0.05490734,0.23335621,0.18668498]
# Probabilitas Paling Tinggi : 0.23335620760917664, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,3,4,2]
#
#
# GENERASI [12] ------
# CHROMOSOME 0 : [0,3,0,2], fitness = 0.058823529411764705
# CHROMOSOME 1 : [ 8, 3,10, 2], fitness = 0.043478260869565216
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [ 1, 3,10, 2], fitness = 0.0625
# CHROMOSOME 4 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 5 : [1,3,4,2], fitness = 0.25
# Fitness Selesai!!
# [16 22  1 15  3  3]
# Total fitness : 1.1648018
# Rata-rata fitness : 0.19413364
# Probabilitas : [0.05050089,0.03732675,0.42925757,0.0536572 ,0.21462879,0.21462879]
# Probabilitas Paling Tinggi : 0.4292575716972351, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [13] ------
# CHROMOSOME 0 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [ 8, 3,10, 2], fitness = 0.043478260869565216
# CHROMOSOME 3 : [1,3,4,0], fitness = 0.08333333333333333
# CHROMOSOME 4 : [8,5,4,2], fitness = 0.1111111111111111
# CHROMOSOME 5 : [1,3,4,2], fitness = 0.25
# Fitness Selesai!!
# [ 3  1 22 11  8  3]
# Total fitness : 1.2379227
# Rata-rata fitness : 0.20632045
# Probabilitas : [0.20195122,0.40390244,0.03512195,0.06731708,0.0897561 ,0.20195122]
# Probabilitas Paling Tinggi : 0.40390244126319885, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [14] ------
# CHROMOSOME 0 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 1 : [8,5,4,2], fitness = 0.1111111111111111
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [ 8, 3,10, 2], fitness = 0.043478260869565216
# CHROMOSOME 5 : [1,3,4,2], fitness = 0.25
# Fitness Selesai!!
# [ 3  8  1  1 22  3]
# Total fitness : 1.6545894
# Rata-rata fitness : 0.2757649
# Probabilitas : [0.15109488,0.06715328,0.30218977,0.30218977,0.02627737,0.15109488]
# Probabilitas Paling Tinggi : 0.30218976736068726, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [15] ------
# CHROMOSOME 0 : [8,5,4,2], fitness = 0.1111111111111111
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,3,1,2], fitness = 0.07692307692307693
# CHROMOSOME 3 : [1,3,4,2], fitness = 0.25
# CHROMOSOME 4 : [7,5,4,2], fitness = 0.125
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [ 8  1 12  3  7  1]
# Total fitness : 1.5630342
# Rata-rata fitness : 0.2605057
# Probabilitas : [0.07108681,0.31989065,0.04921395,0.15994532,0.07997266,0.31989065]
# Probabilitas Paling Tinggi : 0.3198906481266022, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [16] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,3,4,7], fitness = 0.05555555555555555
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [8,5,4,2], fitness = 0.1111111111111111
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [ 1  1 17  1  8  1]
# Total fitness : 2.1666667
# Rata-rata fitness : 0.36111113
# Probabilitas : [0.23076922,0.23076922,0.02564102,0.23076922,0.05128205,0.23076922]
# Probabilitas Paling Tinggi : 0.23076921701431274, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [17] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,0,4,2], fitness = 0.1
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [8,5,4,2], fitness = 0.1111111111111111
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [1 1 9 1 8 1]
# Total fitness : 2.211111
# Rata-rata fitness : 0.3685185
# Probabilitas : [0.22613066,0.22613066,0.04522613,0.22613066,0.05025126,0.22613066]
# Probabilitas Paling Tinggi : 0.2261306643486023, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [18] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [1 1 1 1 1 1]
# Total fitness : 3.0
# Rata-rata fitness : 0.5
# Probabilitas : [0.16666667,0.16666667,0.16666667,0.16666667,0.16666667,0.16666667]
# Probabilitas Paling Tinggi : 0.1666666716337204, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [19] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [1,1,4,2], fitness = 0.125
# CHROMOSOME 4 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [1 1 1 7 1 1]
# Total fitness : 2.625
# Rata-rata fitness : 0.4375
# Probabilitas : [0.1904762 ,0.1904762 ,0.1904762 ,0.04761905,0.1904762 ,0.1904762 ]
# Probabilitas Paling Tinggi : 0.190476194024086, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [20] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 5 : [1,5,2,2], fitness = 0.16666666666666666
# Fitness Selesai!!
# [1 1 1 1 5 5]
# Total fitness : 2.3333335
# Rata-rata fitness : 0.38888893
# Probabilitas : [0.2142857 ,0.2142857 ,0.2142857 ,0.2142857 ,0.07142857,0.07142857]
# Probabilitas Paling Tinggi : 0.2142857015132904, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [21] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [1,5,2,2], fitness = 0.16666666666666666
# CHROMOSOME 5 : [1,5,4,7], fitness = 0.045454545454545456
# Fitness Selesai!!
# [ 1  5  1  1  5 21]
# Total fitness : 1.8787879
# Rata-rata fitness : 0.3131313
# Probabilitas : [0.26612905,0.08870968,0.26612905,0.26612905,0.08870968,0.02419355]
# Probabilitas Paling Tinggi : 0.2661290466785431, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [22] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 4 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [1 1 1 1 1 1]
# Total fitness : 3.0
# Rata-rata fitness : 0.5
# Probabilitas : [0.16666667,0.16666667,0.16666667,0.16666667,0.16666667,0.16666667]
# Probabilitas Paling Tinggi : 0.1666666716337204, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# GENERASI [23] ------
# CHROMOSOME 0 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 1 : [1,5,7,2], fitness = 0.09090909090909091
# CHROMOSOME 2 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 3 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 4 : [1,5,4,2], fitness = 0.5
# CHROMOSOME 5 : [1,5,4,2], fitness = 0.5
# Fitness Selesai!!
# [ 1 10  1  5  1  1]
# Total fitness : 2.2575758
# Rata-rata fitness : 0.37626263
# Probabilitas : [0.22147651,0.04026846,0.22147651,0.07382551,0.22147651,0.22147651]
# Probabilitas Paling Tinggi : 0.2214765101671219, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [1,5,4,2]
#
#
# Selesai!
# CHROMOSOME TERTINGGI DAN TERBAIK ADALAH
# [1 5 4 2]
