# %% [markdown]
# <a href="https://colab.research.google.com/github/WisnuMukti11/KecerdasanBuatan/blob/main/Quiz_Free_UAS_Kecerdasan_Buatan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math 
import random

class Algoritma_genetika :
	jum_chrom = 6 
	gen = ["a", "b", "c", "d"] 
	nilai_per_gen = {
		'min' : 0,
		'max' : 10
	} 
    
	crossover_rate = 50/100 #persen
	mutasi_rate = 10/100 #persen
	total_gen = 24

	next_gen = np.arange(4)
	stop = False

	def __init__(self):
		self.first_chrom = np.random.randint(low=self.nilai_per_gen['min'], high=self.nilai_per_gen['max'], size=(self.jum_chrom, len(self.gen)))
		print("==================================================inisialisasi=================================================")
		print(self.first_chrom)
		print("---------------------------------------------------------------------------------------------------------------")

	def evaluasi_chrom(self, chrom, generasi):
		print("GENERASI ["+str(generasi)+"] ------")
		
		jum_chromo = len(chrom)
		o = np.arange(jum_chromo)   
		fitness = np.arange(jum_chromo, dtype='f')
		
		for x in range(len(chrom)):
		
			
			fo = abs((chrom[x][0]+2*chrom[x][1]+3*chrom[x][2]+4*chrom[x][3])-30)
			o[x] = fo
			

			fitn = 1/(fo+1)
			
			fitness[x] = fitn
			if(fitn == 1):
				self.stop = True
			print("CHROMOSOME {0} : {1}, fitness = {2}".format(x, np.array2string(chrom[x], separator=','), fitn))
		print("FITNESS SELESAI!!")
		print(o)
		
        

		Probab = np.arange(jum_chromo, dtype='f')
		
		total_fitness = fitness.sum() 
		Probab = fitness / total_fitness 
		print("Total fitness : {}".format(str(total_fitness)))
		print("Rata-rata fitness : {}".format(str(np.average(fitness))))
		print("Probabilitas : {}".format(np.array2string(Probab, separator=',')))
		print("Probabilitas Paling Tinggi : {}, Pada chromosome ke {}".format(Probab[Probab.argmax()], str(Probab.argmax())))
		print("CHROMOSOME YANG MUNGKIN TERPILIH : {}".format(np.array2string(chrom[Probab.argmax()], separator=',')))
		print("")
		print("")
		self.next_gen = chrom[Probab.argmax()]


		C = np.arange(jum_chromo, dtype='f')
		total_x = 0
		for x in range(len(Probab)):
			total_x += Probab[x]
			C[x] = total_x


		R = np.random.sample(len(fitness))
		chrom_baru = np.arange(jum_chromo*len(self.gen)).reshape(jum_chromo, len(self.gen))



		for y in range(len(R)):
			for k in range(len(chrom_baru)):
				if(R[y] < C[0]):
					chrom_baru[y] = chrom[0]
				elif((C[k-1] < R[y]) & (R[y] < C[k])):
					chrom_baru[y] = chrom[k]


		R = np.random.sample(jum_chromo)
		index_chrom_parent = [] # [1,2,3, ...]
		for p in range(len(R)):
			if(R[p] < self.crossover_rate):
				index_chrom_parent.append(p)
                

		posisi_cros = np.random.randint(low=1, high=len(self.gen), size=len(index_chrom_parent))


		offspring = np.arange(len(self.gen)*len(index_chrom_parent)).reshape(len(index_chrom_parent), len(self.gen))
		for i_parent in range(len(index_chrom_parent)):
			index_chrome_1 = index_chrom_parent[i_parent]
			if(i_parent == len(index_chrom_parent)-1):
				index_chrome_2 = index_chrom_parent[0]
			else:
				index_chrome_2 = index_chrom_parent[i_parent+1]
			cut_point = posisi_cros[i_parent]
			for p in range(len(chrom_baru[index_chrome_1])):
				if(p >= posisi_cros[i_parent]):
					offspring[i_parent][p] = chrom_baru[index_chrome_2][p]
				else:
					offspring[i_parent][p] = chrom_baru[index_chrome_1][p]

		for x in range(len(offspring)):
			chrom_baru[index_chrom_parent[x]] = offspring[x]
            

		total_gen = len(chrom) * len(chrom[0])
		jum_mutasi = self.mutasi_rate * total_gen 
		jum_mutasi = int(jum_mutasi)

		random_i_mutasi = np.random.randint(low=0, high=total_gen, size=jum_mutasi)

		for x in range(len(random_i_mutasi)):
			index_mutasi = random_i_mutasi[x]
			byk_kromosom = len(chrom)
			byk_gen = len(chrom[0])
			random_value = random.randint(self.nilai_per_gen['min'], self.nilai_per_gen['max'])
			if(index_mutasi <= byk_gen):
				chrom_baru[0][index_mutasi-1]
			else:
				posisi_y = index_mutasi/byk_gen
				posisi_y = int(posisi_y)
				posisi_x = index_mutasi % byk_gen
				chrom_baru[posisi_y][posisi_x] = random_value
		return chrom_baru

	def do_now(self):
		chromosome_current = self.first_chrom
		for generasi in range(0, self.total_gen):
			if(self.stop != True):
				chromosome_current = self.evaluasi_chrom(chromosome_current, generasi)
		print("----------------------------------------------------------------------")
		print("ALL DONE!")
		print("CHROMOSOME TERTINGGI DAN TERBAIK ADALAH")
		print(self.next_gen)

run = Algoritma_genetika()
run.do_now()
# Out:
# ==================================================inisialisasi=================================================
# [[6 0 5 6]
#  [0 4 1 1]
#  [0 9 2 4]
#  [5 5 2 1]
#  [5 2 4 2]
#  [4 7 2 7]]
# ---------------------------------------------------------------------------------------------------------------
# GENERASI [0] ------
# CHROMOSOME 0 : [6,0,5,6], fitness = 0.0625
# CHROMOSOME 1 : [0,4,1,1], fitness = 0.0625
# CHROMOSOME 2 : [0,9,2,4], fitness = 0.09090909090909091
# CHROMOSOME 3 : [5,5,2,1], fitness = 0.16666666666666666
# CHROMOSOME 4 : [5,2,4,2], fitness = 0.5
# CHROMOSOME 5 : [4,7,2,7], fitness = 0.043478260869565216
# FITNESS SELESAI!!
# [15 15 10  5  1 22]
# Total fitness : 0.926054
# Rata-rata fitness : 0.15434234
# Probabilitas : [0.06749067,0.06749067,0.09816824,0.1799751 ,0.53992534,0.04695003]
# Probabilitas Paling Tinggi : 0.5399253368377686, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [5,2,4,2]
#
#
# GENERASI [1] ------
# CHROMOSOME 0 : [5,2,4,1], fitness = 0.16666666666666666
# CHROMOSOME 1 : [5,2,4,2], fitness = 0.5
# CHROMOSOME 2 : [5,5,2,1], fitness = 0.16666666666666666
# CHROMOSOME 3 : [5,2,0,2], fitness = 0.07142857142857142
# CHROMOSOME 4 : [5,5,2,1], fitness = 0.16666666666666666
# CHROMOSOME 5 : [4,2,4,2], fitness = 0.3333333333333333
# FITNESS SELESAI!!
# [ 5  1  5 13  5  2]
# Total fitness : 1.404762
# Rata-rata fitness : 0.234127
# Probabilitas : [0.11864406,0.35593218,0.11864406,0.05084746,0.11864406,0.23728812]
# Probabilitas Paling Tinggi : 0.35593217611312866, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [5,2,4,2]
#
#
# GENERASI [2] ------
# CHROMOSOME 0 : [4,2,4,2], fitness = 0.3333333333333333
# CHROMOSOME 1 : [5,5,2,1], fitness = 0.16666666666666666
# CHROMOSOME 2 : [3,5,2,1], fitness = 0.125
# CHROMOSOME 3 : [5,2,4,2], fitness = 0.5
# CHROMOSOME 4 : [5,5,2,1], fitness = 0.16666666666666666
# CHROMOSOME 5 : [5,2,3,2], fitness = 0.2
# FITNESS SELESAI!!
# [2 5 7 1 5 4]
# Total fitness : 1.4916667
# Rata-rata fitness : 0.24861111
# Probabilitas : [0.2234637 ,0.11173185,0.08379889,0.33519554,0.11173185,0.13407822]
# Probabilitas Paling Tinggi : 0.33519554138183594, Pada chromosome ke 3
# CHROMOSOME YANG MUNGKIN TERPILIH : [5,2,4,2]
#
#
# GENERASI [3] ------
# CHROMOSOME 0 : [5,2,3,2], fitness = 0.2
# CHROMOSOME 1 : [5,2,3,2], fitness = 0.2
# CHROMOSOME 2 : [5,5,2,1], fitness = 0.16666666666666666
# CHROMOSOME 3 : [3,2,4,2], fitness = 0.25
# CHROMOSOME 4 : [5,2,3,2], fitness = 0.2
# CHROMOSOME 5 : [5,2,3,2], fitness = 0.2
# FITNESS SELESAI!!
# [4 4 5 3 4 4]
# Total fitness : 1.2166667
# Rata-rata fitness : 0.20277779
# Probabilitas : [0.16438356,0.16438356,0.1369863 ,0.20547944,0.16438356,0.16438356]
# Probabilitas Paling Tinggi : 0.2054794430732727, Pada chromosome ke 3
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,2,4,2]
#
#
# GENERASI [4] ------
# CHROMOSOME 0 : [3,2,4,2], fitness = 0.25
# CHROMOSOME 1 : [ 5, 2, 3,10], fitness = 0.034482758620689655
# CHROMOSOME 2 : [5,2,3,2], fitness = 0.2
# CHROMOSOME 3 : [5,2,3,2], fitness = 0.2
# CHROMOSOME 4 : [1,2,4,2], fitness = 0.16666666666666666
# CHROMOSOME 5 : [3,2,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [ 3 28  4  4  5  3]
# Total fitness : 1.1011494
# Rata-rata fitness : 0.1835249
# Probabilitas : [0.2270355 ,0.03131524,0.18162839,0.18162839,0.151357  ,0.2270355 ]
# Probabilitas Paling Tinggi : 0.2270354926586151, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,2,4,2]
#
#
# GENERASI [5] ------
# CHROMOSOME 0 : [3,2,4,2], fitness = 0.25
# CHROMOSOME 1 : [1,2,4,2], fitness = 0.16666666666666666
# CHROMOSOME 2 : [3,2,4,2], fitness = 0.25
# CHROMOSOME 3 : [5,2,3,2], fitness = 0.2
# CHROMOSOME 4 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 5 : [5,8,3,2], fitness = 0.1111111111111111
# FITNESS SELESAI!!
# [3 5 3 4 3 8]
# Total fitness : 1.2277778
# Rata-rata fitness : 0.20462964
# Probabilitas : [0.2036199 ,0.1357466 ,0.2036199 ,0.16289592,0.2036199 ,0.09049773]
# Probabilitas Paling Tinggi : 0.20361989736557007, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,2,4,2]
#
#
# GENERASI [6] ------
# CHROMOSOME 0 : [3,2,4,2], fitness = 0.25
# CHROMOSOME 1 : [1,2,4,2], fitness = 0.16666666666666666
# CHROMOSOME 2 : [3,2,4,2], fitness = 0.25
# CHROMOSOME 3 : [5,8,3,2], fitness = 0.1111111111111111
# CHROMOSOME 4 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 5 : [3,2,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [3 5 3 8 3 3]
# Total fitness : 1.2777778
# Rata-rata fitness : 0.21296297
# Probabilitas : [0.19565217,0.13043478,0.19565217,0.08695652,0.19565217,0.19565217]
# Probabilitas Paling Tinggi : 0.19565217196941376, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,2,4,2]
#
#
# GENERASI [7] ------
# CHROMOSOME 0 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 1 : [3,4,4,2], fitness = 0.5
# CHROMOSOME 2 : [3,5,4,4], fitness = 0.08333333333333333
# CHROMOSOME 3 : [1,2,4,2], fitness = 0.16666666666666666
# CHROMOSOME 4 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 5 : [3,8,3,2], fitness = 0.14285714285714285
# FITNESS SELESAI!!
# [ 5  1 11  5  3  6]
# Total fitness : 1.3095239
# Rata-rata fitness : 0.21825399
# Probabilitas : [0.12727273,0.38181815,0.06363636,0.12727273,0.19090907,0.1090909 ]
# Probabilitas Paling Tinggi : 0.38181814551353455, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,4,4,2]
#
#
# GENERASI [8] ------
# CHROMOSOME 0 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 1 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 2 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 3 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 4 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 5 : [3,5,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [5 3 3 3 5 3]
# Total fitness : 1.3333334
# Rata-rata fitness : 0.22222222
# Probabilitas : [0.125 ,0.1875,0.1875,0.1875,0.125 ,0.1875]
# Probabilitas Paling Tinggi : 0.1875, Pada chromosome ke 1
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [9] ------
# CHROMOSOME 0 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 1 : [3,6,4,2], fitness = 0.16666666666666666
# CHROMOSOME 2 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 3 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 4 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 5 : [3,5,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [3 5 5 5 5 3]
# Total fitness : 1.1666667
# Rata-rata fitness : 0.19444446
# Probabilitas : [0.2142857 ,0.14285713,0.14285713,0.14285713,0.14285713,0.2142857 ]
# Probabilitas Paling Tinggi : 0.2142857015132904, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [10] ------
# CHROMOSOME 0 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 1 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 2 : [5,5,0,2], fitness = 0.125
# CHROMOSOME 3 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 4 : [3,6,4,2], fitness = 0.16666666666666666
# CHROMOSOME 5 : [5,5,4,2], fitness = 0.16666666666666666
# FITNESS SELESAI!!
# [3 3 7 3 5 5]
# Total fitness : 1.2083333
# Rata-rata fitness : 0.20138888
# Probabilitas : [0.20689656,0.20689656,0.10344828,0.20689656,0.13793105,0.13793105]
# Probabilitas Paling Tinggi : 0.2068965584039688, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [11] ------
# CHROMOSOME 0 : [5,5,4,2], fitness = 0.16666666666666666
# CHROMOSOME 1 : [5,4,0,2], fitness = 0.1
# CHROMOSOME 2 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 3 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 4 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 5 : [5,5,4,2], fitness = 0.16666666666666666
# FITNESS SELESAI!!
# [5 9 3 3 3 5]
# Total fitness : 1.1833333
# Rata-rata fitness : 0.19722222
# Probabilitas : [0.14084508,0.08450705,0.21126762,0.21126762,0.21126762,0.14084508]
# Probabilitas Paling Tinggi : 0.2112676203250885, Pada chromosome ke 2
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [12] ------
# CHROMOSOME 0 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 1 : [3,7,4,2], fitness = 0.125
# CHROMOSOME 2 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 3 : [5,5,4,3], fitness = 0.1
# CHROMOSOME 4 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 5 : [3,5,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [3 7 3 9 3 3]
# Total fitness : 1.225
# Rata-rata fitness : 0.20416667
# Probabilitas : [0.20408162,0.10204081,0.20408162,0.08163265,0.20408162,0.20408162]
# Probabilitas Paling Tinggi : 0.20408162474632263, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [13] ------
# CHROMOSOME 0 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 1 : [3,7,4,2], fitness = 0.125
# CHROMOSOME 2 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 3 : [ 3, 5, 4,10], fitness = 0.027777777777777776
# CHROMOSOME 4 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 5 : [3,5,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [ 3  7  3 35  3  3]
# Total fitness : 1.1527778
# Rata-rata fitness : 0.19212963
# Probabilitas : [0.21686746,0.10843373,0.21686746,0.02409638,0.21686746,0.21686746]
# Probabilitas Paling Tinggi : 0.21686746180057526, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [14] ------
# CHROMOSOME 0 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 1 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 2 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 3 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 4 : [3,7,4,2], fitness = 0.125
# CHROMOSOME 5 : [3,5,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [3 3 3 3 7 3]
# Total fitness : 1.375
# Rata-rata fitness : 0.22916667
# Probabilitas : [0.18181819,0.18181819,0.18181819,0.18181819,0.09090909,0.18181819]
# Probabilitas Paling Tinggi : 0.1818181872367859, Pada chromosome ke 0
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,4,2]
#
#
# GENERASI [15] ------
# CHROMOSOME 0 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 1 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 2 : [4,5,4,2], fitness = 0.2
# CHROMOSOME 3 : [3,5,4,2], fitness = 0.25
# CHROMOSOME 4 : [3,5,3,2], fitness = 1.0
# CHROMOSOME 5 : [3,5,4,2], fitness = 0.25
# FITNESS SELESAI!!
# [3 3 4 3 0 3]
# Total fitness : 2.2
# Rata-rata fitness : 0.36666667
# Probabilitas : [0.11363636,0.11363636,0.09090909,0.11363636,0.45454544,0.11363636]
# Probabilitas Paling Tinggi : 0.45454543828964233, Pada chromosome ke 4
# CHROMOSOME YANG MUNGKIN TERPILIH : [3,5,3,2]
#
#
# ----------------------------------------------------------------------
# ALL DONE!
# CHROMOSOME TERTINGGI DAN TERBAIK ADALAH
# [3 5 3 2]
